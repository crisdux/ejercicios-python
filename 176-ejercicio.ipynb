# %%
# Utiliza el diccionario de palabras del reto
# anterior para agregar una nueva palabra y su
# definición, imprime la cantidad de elementos
#             del diccionario

# %%
lenguajes = {
    "python": "el mejor lenguaje de programacion",
    "laravel": "framework web back",
    "angular": "framework web front",
    "java": "zzz",
    "javascript": "lenguaje raro"
}

lenguajes["php"] = "El 2do mejor lenguaje"
print(lenguajes)
print(len(lenguajes ))
# Out:
# {'python': 'el mejor lenguaje de programacion', 'laravel': 'framework web back', 'angular': 'framework web front', 'java': 'zzz', 'javascript': 'lenguaje raro', 'php': 'El 2do mejor lenguaje'}
# 6
